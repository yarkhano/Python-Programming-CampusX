# %%
#Q1
salary = 1000000
salary_fixed_tax = (salary) - (0.1*salary) - (0.05*salary) - (0.03*salary)

if salary < 500000:
    dynamic_tax_salary = salary_fixed_tax
elif salary >= 500000 and salary <= 1000000:
    dynamic_tax_salary = salary_fixed_tax - (0.1*salary_fixed_tax)
elif salary > 1000000 and salary<=2000000:
    dynamic_tax_salary = salary_fixed_tax - (0.2*salary_fixed_tax)
else:
    dynamic_tax_salary = salary_fixed_tax - (0.3*salary_fixed_tax)

monthly_salary = dynamic_tax_salary/12
print(f"monthly slary is {monthly_salary}")
# Out:
# monthly slary is 61500.0

# %%
#Q2

n1 = 60
n2 = 60
n3= 10

sum = n1 + n2 + n3
if sum == 180:
    print("yes these angles can make the triangle ")
else:
    print("not possible for the combination to make triangle")
# Out:
# not possible for the combination to make triangle
