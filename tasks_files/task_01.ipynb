# %% [markdown]
# # TASK 01

# %%
#Q1

print("Data","Science","Mentorship","Program","campusX",sep="-")
# Out:
# Data-Science-Mentorship-Program-campusX

# %%
#Q2-> celsius to fahreheit

celsius = int(input("please enter value in celsius"))

fahrenheit = (celsius*1.8) + 32

print(f"The celsius value {celsius} in Fahrenheit {fahrenheit:.1f} ")
# Out:
# The celsius value 3 in Fahrenheit 37.4

# %%
#Q3
num1 = int(input("please enter first number"))
num2 = int(input("please enter second number"))


temp = num1
num1 = num2
num2 = temp


print(num1, num2)
# Out:
# 2 1

# %%
#Q4

c1 = int(input("please enter first number"))
c2 = int(input("please enter second number"))

d = ((c2-c1)**2)**0.5

print(d)
# Out:
# 1.0

# %%
#Q5

prin = int(input("enter principle"))
vint = int(input("value of interst"))
peroid = int(input("enter peroid"))

interest = (prin*vint*peroid)/100
print(interest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Q5
#       2
# ----> 3 prin = int(input("enter principle"))
#       4 vint = int(input("value of interst"))
#       5 peroid = int(input("enter peroid"))
#       6
#
# File ~\PycharmProjects\Python-Programming-CampusX\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...

# %%
#Q6
totalheads = int(input("enter total heads"))
totallegs = int(input("enter total legs"))



#heads= no of animals e.g 4
#now think that what combination of 12 legs can be made like
