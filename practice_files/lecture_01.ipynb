# %%
print("Hi","my name is python","Your ",sep="/",end="")
print("He is on the way")
# Out:
# Hi/my name is python/Your He is on the way

# %%
#python can handle upto 1*10 power 308
#integer
print(1e308)
# Out:
# 1e+308

# %%
#float 1e308

# %%
#[]->squarre brackets
#()->small brackets
#{}->curly braces

# %%
#bolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Dynamic typing->You do not declare the data type of the variable the interpreter auto dtect the data type

a = 5
name = 'ali'

#static typing
#int a = 5;

# %%
#Dynamic binding-> where you can assign different type of data to same variable

a = 'Ali'
print(a)

a = 5
print(a)

#now value as been changes from string to integer and have no affect
# Out:
# Ali
# 5

# %%
#compiler-> compile whole program and convert to binary at once
#interpreter-> convert to binary line by line

# %%
#keywords are rserved by the interpreter or compiler to know what to do ;

# %%
#identifier-> is name given to any variable or whatever
#in special charcters you can only use _ not anyone else.
#you cant start from numbers

# %%
#take two number from user and add them
#input by default take everything as string,because string is universal standarad that mean it can store any type of data.

num1 = input("please enter first number")
num2 = input("please enter second number")

result = int(num1)+int(num2)
print(f"result is {result}")
# Out:
# result is 4

# %%
type(num1)

#As we converted the string into int but still num1 is string rathere than type conversion.this is because the actual value of num1 is not being changed ,but a copy of actual variable num1 is being created and changes are made to it .
# Out:
# str

# %%
#type conversion
#implicit vs explicit
#implicit-> prebuilt
#explicit-> you have to define

type(int('4'))
# Out:
# int

# %% [markdown]
# # Literals

# %%
#literal is the value assigned to any variable

# %% [markdown]
# # Boleans

# %%
#In python True = 1 and False =0 ,actually you cann add too

a = True + 1
b = False + 1

print(a)
print(b)
# Out:
# 2
# 1

# %%
#None can be use for declaration

c = None
