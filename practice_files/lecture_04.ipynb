# %% [markdown]
# ## LISTS ##

# %% [markdown]
# List is dynamic while array byself is static.
# list is heterogenous(can store any data type),while array is homogenous.
# lists has slow execution and consume more memmory.

# %%
a = [1,2,3]

# %%
print(id(0))
print(id(1))
# Out:
# 140735299537304
# 140735299537336
