# %% [markdown]
# # Operators

# %%
print(5//2)  #integer division
# Out:
# 2

# %%
#logical operators
print(1 and 1)
# Out:
# 1

# %%
#bitwise operators
print(2&3)
print(2|3)
print(2^3)

#left shift
print(5>>2)

#right shift
print(5<<2)
# Out:
# 2
# 3
# 1
# 1
# 20

# %%
#Memebership Operators
#in/not in

print('y' in 'yar')
print(1 in [2,3,4,5])

print(2 not in [3,4,5])
# Out:
# True
# False
# True

# %%
number = 345 #int(input('Enter a number: '))

a = number%10

number = number//10

b = number%10

number = number//10

print(a)
print(b)
print(number)

result = a+b+number

print(result)
# Out:
# 5
# 4
# 3
# 12

# %%
email = input('enter email')
password = input('enter password')

if email == 'yar.com' and password == '123':
    print("welcome to the dashboard")

elif email == 'yar.com' and password != '123':
    print('incorrect password,enter again')
    input()
    if email == 'yar.com' and password == '123':
        print("welcome to the dashboard")
    else:
        print('aap rehna da')
else:
    print("wrong password or email")
# Out:
# incorrect password,enter again
# aap rehna da

# %%
#modules-> files where functios ar defined its code and you reuse those functions:

# %%
#math
import math

math.factorial(4)
# Out:
# 24

# %%
#random
import random
print(random.randint(1,100))
# Out:
# 80

# %%
#keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-06-30 14:25:24.323302

# %% [markdown]
# # LOOPS

# %%
#while loop
x = 1

while x<9:
    print(x)
    x+=1

else:
    print("So,limit reached")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# So,limit reached

# %%
import random
num = (random.randint(1,100))

# %%
#while loop

# %%
import math
curr_pop = 10000
for i in range(10,0,-1):
    print(i,curr_pop)
    curr_pop = math.ceil(curr_pop/1.1)
# Out:
# 10 10000
# 9 9091
# 8 8265
# 7 7514
# 6 6831
# 5 6210
# 4 5646
# 3 5133
# 2 4667
# 1 4243

# %%
#1/1!+2/2!...

n = 8
result = 0
fact = 1

for i in range(1,n+1):
    fact = fact * i
    result = result + i/fact
print(result)
# Out:
# 2.7182539682539684
